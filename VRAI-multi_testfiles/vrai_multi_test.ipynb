# %%
from VRAI_multi import VRAI_multi
import pandas as pd

# %%
test=VRAI_multi('./test_file/')
test.file_df
# Out:
#                              TS1                           int  \
# 0  ol17ryu_e_int2_SSR_11_TS1.mol  ol17ryu_e_int2_SSR_6_int.mol
# 1  ol17ryu_e_int2_SSR_11_TS1.mol  ol17ryu_e_int2_SSR_6_int.mol
# 2  ol17ryu_e_int2_SSR_11_TS1.mol  ol17ryu_e_int2_SSR_6_int.mol
#
#                                     p1                                   p2  \
# 0  ol17ryu_e_int2_SSR_C_1_TS2_prod.mol  ol17ryu_e_int2_SSR_H_2_TS2_prod.mol
# 1  ol17ryu_e_int2_SSR_C_1_TS2_prod.mol  ol17ryu_e_int2_SSR_O_1_TS2_prod.mol
# 2  ol17ryu_e_int2_SSR_H_2_TS2_prod.mol  ol17ryu_e_int2_SSR_O_1_TS2_prod.mol
#
#                         TS1_freq                      int_freq  \
# 0  ol17ryu_e_int2_SSR_11_TS1.out  ol17ryu_e_int2_SSR_6_int.out
# 1  ol17ryu_e_int2_SSR_11_TS1.out  ol17ryu_e_int2_SSR_6_int.out
# 2  ol17ryu_e_int2_SSR_11_TS1.out  ol17ryu_e_int2_SSR_6_int.out
#
#                         ts2a_freq                       ts2b_freq
# 0  ol17ryu_e_int2_SSR_C_1_TS2.out  ol17ryu_e_int2_SSR_H_2_TS2.out
# ...

# %%
test.autopipe(with_spe=True)
test.processed_result_df
# Out:
# [16:25:26] CTAB version string invalid at line 4
# [16:25:26] CTAB version string invalid at line 4
# [16:25:26] CTAB version string invalid at line 4
# [16:25:26] CTAB version string invalid at line 4
# The higher-energy TS2 is -17.87 kJ/mol (free energy) from TS1.
#
# **** Analysis Completed ****
# Major product is ./test_file/ol17ryu_e_int2_SSR_H_2_TS2_prod.mol
# Minor product is ./test_file/ol17ryu_e_int2_SSR_C_1_TS2_prod.mol
#
# mu1_ = -0.19597356998382445
# mu2_ = 0.02012571704126214
# lambda1_ = 0.34524844932885496
# lambda2_ = 0.37698148760467476
# |g_| = 0.4499705675120856
# phi = 2.3485925481176264
#
# Product Ratio Calculation Completed:
# Major Product : Minor Product ratio
# 98.6 : 1.4
#
# ****************************
# [16:25:27] CTAB version string invalid at line 4
# [16:25:27] CTAB version string invalid at line 4
# [16:25:27] CTAB version string invalid at line 4
# [16:25:27] CTAB version string invalid at line 4
# ...

# %%
test.raw_result_df
# Out:
#                     TS1_name                  int_name  \
# 0  ol17ryu_e_int2_SSR_11_TS1  ol17ryu_e_int2_SSR_6_int
# 0  ol17ryu_e_int2_SSR_11_TS1  ol17ryu_e_int2_SSR_6_int
# 0  ol17ryu_e_int2_SSR_11_TS1  ol17ryu_e_int2_SSR_6_int
#
#                              major                            minor  \
# 0  ol17ryu_e_int2_SSR_H_2_TS2_prod  ol17ryu_e_int2_SSR_C_1_TS2_prod
# 0  ol17ryu_e_int2_SSR_C_1_TS2_prod  ol17ryu_e_int2_SSR_O_1_TS2_prod
# 0  ol17ryu_e_int2_SSR_H_2_TS2_prod  ol17ryu_e_int2_SSR_O_1_TS2_prod
#
#    major_per  minor_per  TST_valid
# 0       98.6        1.4      False
# 0       99.5        0.5       True
# 0       99.9        0.1       True

# %%
test2=VRAI_multi('test_file.csv')
test2.autopipe(path='./test_file/',with_spe=True)
test2.processed_result_df
# Out:
# [16:33:43] CTAB version string invalid at line 4
# [16:33:43] CTAB version string invalid at line 4
# [16:33:43] CTAB version string invalid at line 4
# [16:33:43] CTAB version string invalid at line 4
# The higher-energy TS2 is -17.87 kJ/mol (free energy) from TS1.
#
# **** Analysis Completed ****
# Major product is ./test_file/ol17ryu_e_int2_SSR_H_2_TS2_prod.mol
# Minor product is ./test_file/ol17ryu_e_int2_SSR_C_1_TS2_prod.mol
#
# mu1_ = -0.19597356998382445
# mu2_ = 0.02012571704126214
# lambda1_ = 0.34524844932885496
# lambda2_ = 0.37698148760467476
# |g_| = 0.4499705675120856
# phi = 2.3485925481176264
#
# Product Ratio Calculation Completed:
# Major Product : Minor Product ratio
# 98.6 : 1.4
#
# ****************************
# [16:33:45] CTAB version string invalid at line 4
# [16:33:45] CTAB version string invalid at line 4
# [16:33:45] CTAB version string invalid at line 4
# [16:33:45] CTAB version string invalid at line 4
# ...

# %%
test2.raw_result_df
# Out:
#                     TS1_name                  int_name  \
# 0  ol17ryu_e_int2_SSR_11_TS1  ol17ryu_e_int2_SSR_6_int
# 0  ol17ryu_e_int2_SSR_11_TS1  ol17ryu_e_int2_SSR_6_int
# 0  ol17ryu_e_int2_SSR_11_TS1  ol17ryu_e_int2_SSR_6_int
#
#                              major                            minor  \
# 0  ol17ryu_e_int2_SSR_H_2_TS2_prod  ol17ryu_e_int2_SSR_C_1_TS2_prod
# 0  ol17ryu_e_int2_SSR_C_1_TS2_prod  ol17ryu_e_int2_SSR_O_1_TS2_prod
# 0  ol17ryu_e_int2_SSR_H_2_TS2_prod  ol17ryu_e_int2_SSR_O_1_TS2_prod
#
#    major_per  minor_per  TST_valid
# 0       98.6        1.4      False
# 0       99.5        0.5       True
# 0       99.9        0.1       True
